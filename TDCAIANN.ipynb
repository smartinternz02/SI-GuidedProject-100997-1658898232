# %%
IMAGE CLAASIFICATION

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_46e024aa818045c2a43c76ab1a581d19 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='wVGcdJPhZWtKFwvpLFavcTwun8WvxLjj0n5Tm7-OcEsb',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.eu.cloud-object-storage.appdomain.cloud')

streaming_body_1 = client_46e024aa818045c2a43c76ab1a581d19.get_object(Bucket='tdc-donotdelete-pr-kwufuguctasata', Key='Fertilizers_Recommendation_ System_For_Disease_ Prediction.zip')['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/

# %%
from io import BytesIO
import zipfile
unzip=zipfile.ZipFile(BytesIO(streaming_body_1.read()),'r')
file_paths=unzip.namelist()
for path in file_paths:
    unzip.extract(path)

# %%
ls
# Out:
# 'Dataset Plant Disease'/

# %% [markdown]
# # image augumentation

# %%
from tensorflow.keras.preprocessing.image import  ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,zoom_range=0.2,horizontal_flip=True,vertical_flip=False)

# %%
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
ls
# Out:
# 'Dataset Plant Disease'/

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
x_tain=train_datagen.flow_from_directory(r"/home/wsuser/work/Dataset Plant Disease/Training",target_size=(64,64),class_mode='categorical',batch_size=24)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/wsuser/ipykernel_164/2936278831.py in <module>
# ----> 1 x_tain=train_datagen.flow_from_directory(r"/home/wsuser/work/Dataset Plant Disease/Training",target_size=(64,64),class_mode='categorical',batch_size=24)
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     974             and `y` is a numpy array of corresponding labels.
#     975     """
# --> 976     return DirectoryIterator(
#     977         directory,
#     978         self,
#
# ...

# %%
x_test=test_datagen.flow_from_directory(r"/home/wsuser/work/Dataset Plant Disease/Testing",target_size=(64,64),class_mode='categorical',batch_size=15)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/wsuser/ipykernel_164/893381275.py in <module>
# ----> 1 x_test=test_datagen.flow_from_directory(r"/home/wsuser/work/Dataset Plant Disease/Testing",target_size=(64,64),class_mode='categorical',batch_size=15)
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     974             and `y` is a numpy array of corresponding labels.
#     975     """
# --> 976     return DirectoryIterator(
#     977         directory,
#     978         self,
#
# ...
